# %%
#import utils

import os
import openai
#import utils
openai.api_key = utils.get_open_api_key()

print(os.getcwd())
# Out:
# 🦑 Initialized with db url sqlite:///default.sqlite .
# 🛑 Secret keys may be written to the database. See the `database_redact_keys` option of `TruSession` to prevent this.
# ✅ In Answer Relevance, input prompt will be set to __record__.main_input or `Select.RecordInput` .
# ✅ In Answer Relevance, input response will be set to __record__.main_output or `Select.RecordOutput` .
# ✅ In Context Relevance, input prompt will be set to __record__.main_input or `Select.RecordInput` .
# ✅ In Context Relevance, input response will be set to __record__.calls[-1].rets.source_nodes[:].node.text .
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       3 import os
#       4 import openai
# ----> 5 import utils
#       6 openai.api_key = utils.get_open_api_key()
#       8 print(os.getcwd())
#
# File ~/meetup_cs224n/RAG/utils.py:47
#      39 qs_relevance = (
#      40     Feedback(openai.relevance_with_cot_reasons, name = "Context Relevance")
#      41     .on_input()
#      42     .on(TruLlama.select_source_nodes().node.text)
#      43     .aggregate(np.mean)
#      44 )
#      46 #grounded = Groundedness(groundedness_provider=openai, summarize_provider=openai)
# ---> 47 grounded = GroundTruthAgreement(groundedness_provider=openai)
#      49 groundedness = (
#      50     Feedback(grounded.groundedness_measure_with_cot_reasons, name="GroundTruthAgreement")
#      51         .on(TruLlama.select_source_nodes().node.text)
#      52         .on_output()
#      53         .aggregate(grounded.grounded_statements_aggregator)
#      54 )
#      56 feedbacks = [qa_relevance, qs_relevance, groundedness]
#
# TypeError: __init__() missing 1 required positional argument: 'ground_truth'

# %%
import os
import dotenv
from dotenv import load_dotenv, find_dotenv

import numpy as np
from trulens_eval import (
    Feedback,
    TruLlama,
    OpenAI
)

from trulens_eval.feedback import Groundedness
#from trulens_eval.feedback import GroundTruthAgreement
import nest_asyncio

nest_asyncio.apply()


def get_openai_api_key():
    _ = load_dotenv(find_dotenv())

    return os.getenv("OPENAI_API_KEY")


def get_hf_api_key():
    _ = load_dotenv(find_dotenv())

    return os.getenv("HUGGINGFACE_API_KEY")

openai = OpenAI()

qa_relevance = (
    Feedback(openai.relevance_with_cot_reasons, name="Answer Relevance")
    .on_input_output()
)

qs_relevance = (
    Feedback(openai.relevance_with_cot_reasons, name = "Context Relevance")
    .on_input()
    .on(TruLlama.select_source_nodes().node.text)
    .aggregate(np.mean)
)

grounded = Groundedness(groundedness_provider=openai, summarize_provider=openai)
#grounded = GroundTruthAgreement(groundedness_provider=openai)

groundedness = (
    Feedback(grounded.groundedness_measure_with_cot_reasons, name="GroundTruthAgreement")
        .on(TruLlama.select_source_nodes().node.text)
        .on_output()
        .aggregate(grounded.grounded_statements_aggregator)
)

feedbacks = [qa_relevance, qs_relevance, groundedness]

def get_trulens_recorder(query_engine, feedbacks, app_id):
    tru_recorder = TruLlama(
        query_engine,
        app_id=app_id,
        feedbacks=feedbacks
    )
    return tru_recorder

def get_prebuilt_trulens_recorder(query_engine, app_id):
    tru_recorder = TruLlama(
        query_engine,
        app_id=app_id,
        feedbacks=feedbacks
        )
    return tru_recorder

from llama_index import ServiceContext, VectorStoreIndex, StorageContext
from llama_index.node_parser import SentenceWindowNodeParser
from llama_index.indices.postprocessor import MetadataReplacementPostProcessor
from llama_index.indices.postprocessor import SentenceTransformerRerank
from llama_index import load_index_from_storage
import os


def build_sentence_window_index(
    document, llm, embed_model="local:BAAI/bge-small-en-v1.5", save_dir="sentence_index"
):
    # create the sentence window node parser w/ default settings
    node_parser = SentenceWindowNodeParser.from_defaults(
        window_size=3,
        window_metadata_key="window",
        original_text_metadata_key="original_text",
    )
    sentence_context = ServiceContext.from_defaults(
        llm=llm,
        embed_model=embed_model,
        node_parser=node_parser,
    )
    if not os.path.exists(save_dir):
        sentence_index = VectorStoreIndex.from_documents(
            [document], service_context=sentence_context
        )
        sentence_index.storage_context.persist(persist_dir=save_dir)
    else:
        sentence_index = load_index_from_storage(
            StorageContext.from_defaults(persist_dir=save_dir),
            service_context=sentence_context,
        )

    return sentence_index


def get_sentence_window_query_engine(
    sentence_index,
    similarity_top_k=6,
    rerank_top_n=2,
):
    # define postprocessors
    postproc = MetadataReplacementPostProcessor(target_metadata_key="window")
    rerank = SentenceTransformerRerank(
        top_n=rerank_top_n, model="BAAI/bge-reranker-base"
    )

    sentence_window_engine = sentence_index.as_query_engine(
        similarity_top_k=similarity_top_k, node_postprocessors=[postproc, rerank]
    )
    return sentence_window_engine


from llama_index.node_parser import HierarchicalNodeParser

from llama_index.node_parser import get_leaf_nodes
from llama_index import StorageContext
from llama_index.retrievers import AutoMergingRetriever
from llama_index.indices.postprocessor import SentenceTransformerRerank
from llama_index.query_engine import RetrieverQueryEngine


def build_automerging_index(
    documents,
    llm,
    embed_model="local:BAAI/bge-small-en-v1.5",
    save_dir="merging_index",
    chunk_sizes=None,
):
    chunk_sizes = chunk_sizes or [2048, 512, 128]
    node_parser = HierarchicalNodeParser.from_defaults(chunk_sizes=chunk_sizes)
    nodes = node_parser.get_nodes_from_documents(documents)
    leaf_nodes = get_leaf_nodes(nodes)
    merging_context = ServiceContext.from_defaults(
        llm=llm,
        embed_model=embed_model,
    )
    storage_context = StorageContext.from_defaults()
    storage_context.docstore.add_documents(nodes)

    if not os.path.exists(save_dir):
        automerging_index = VectorStoreIndex(
            leaf_nodes, storage_context=storage_context, service_context=merging_context
        )
        automerging_index.storage_context.persist(persist_dir=save_dir)
    else:
        automerging_index = load_index_from_storage(
            StorageContext.from_defaults(persist_dir=save_dir),
            service_context=merging_context,
        )
    return automerging_index


def get_automerging_query_engine(
    automerging_index,
    similarity_top_k=12,
    rerank_top_n=2,
):
    base_retriever = automerging_index.as_retriever(similarity_top_k=similarity_top_k)
    retriever = AutoMergingRetriever(
        base_retriever, automerging_index.storage_context, verbose=True
    )
    rerank = SentenceTransformerRerank(
        top_n=rerank_top_n, model="BAAI/bge-reranker-base"
    )
    auto_merging_engine = RetrieverQueryEngine.from_args(
        retriever, node_postprocessors=[rerank]
    )
    return auto_merging_engine
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 12
#       5 import numpy as np
#       6 from trulens_eval import (
#       7     Feedback,
#       8     TruLlama,
#       9     OpenAI
#      10 )
# ---> 12 from trulens_eval.feedback import Groundedness
#      13 #from trulens_eval.feedback import GroundTruthAgreement
#      14 import nest_asyncio
#
# ImportError: cannot import name 'Groundedness' from 'trulens_eval.feedback' (/Users/dc/meetup_cs224n/RAG/.venv/lib/python3.9/site-packages/trulens_eval/feedback/__init__.py)

# %%
# !pip list
# Out:
# Package                   Version
# ------------------------- --------------
# annotated-types           0.7.0
# anyio                     4.7.0
# appnope                   0.1.4
# argon2-cffi               23.1.0
# argon2-cffi-bindings      21.2.0
# arrow                     1.3.0
# asttokens                 3.0.0
# async-lru                 2.0.4
# attrs                     24.3.0
# babel                     2.16.0
# beautifulsoup4            4.12.3
# bleach                    6.2.0
# certifi                   2024.12.14
# cffi                      1.17.1
# charset-normalizer        3.4.0
# comm                      0.2.2
# debugpy                   1.8.11
# decorator                 5.1.1
# defusedxml                0.7.1
# distro                    1.9.0
# exceptiongroup            1.2.2
# executing                 2.1.0
# fastjsonschema            2.21.1
# fqdn                      1.5.1
# h11                       0.14.0
# httpcore                  1.0.7
# httpx                     0.28.1
# idna                      3.10
# importlib_metadata        8.5.0
# ipykernel                 6.29.5
# ipython                   8.18.1
# ipywidgets                8.1.5
# isoduration               20.11.0
# jedi                      0.19.2
# Jinja2                    3.1.4
# jiter                     0.8.2
# json5                     0.10.0
# jsonpointer               3.0.0
# jsonschema                4.23.0
# jsonschema-specifications 2024.10.1
# jupyter                   1.1.1
# jupyter_client            8.6.3
# jupyter-console           6.6.3
# jupyter_core              5.7.2
# jupyter-events            0.11.0
# jupyter-lsp               2.2.5
# jupyter_server            2.14.2
# jupyter_server_terminals  0.5.3
# jupyterlab                4.3.4
# jupyterlab_pygments       0.3.0
# jupyterlab_server         2.27.3
# jupyterlab_widgets        3.0.13
# MarkupSafe                3.0.2
# matplotlib-inline         0.1.7
# mistune                   3.0.2
# nbclient                  0.10.2
# nbconvert                 7.16.4
# nbformat                  5.10.4
# nest-asyncio              1.6.0
# notebook                  7.3.1
# notebook_shim             0.2.4
# openai                    1.58.1
# overrides                 7.7.0
# packaging                 24.2
# pandocfilters             1.5.1
# parso                     0.8.4
# pexpect                   4.9.0
# pip                       23.0.1
# platformdirs              4.3.6
# prometheus_client         0.21.1
# prompt_toolkit            3.0.48
# psutil                    6.1.0
# ptyprocess                0.7.0
# pure_eval                 0.2.3
# pycparser                 2.22
# pydantic                  2.10.4
# pydantic_core             2.27.2
# Pygments                  2.18.0
# python-dateutil           2.9.0.post0
# python-dotenv             1.0.1
# python-json-logger        3.2.1
# PyYAML                    6.0.2
# pyzmq                     26.2.0
# referencing               0.35.1
# requests                  2.32.3
# rfc3339-validator         0.1.4
# rfc3986-validator         0.1.1
# rpds-py                   0.22.3
# Send2Trash                1.8.3
# setuptools                58.1.0
# six                       1.17.0
# sniffio                   1.3.1
# soupsieve                 2.6
# stack-data                0.6.3
# terminado                 0.18.1
# tinycss2                  1.4.0
# tomli                     2.2.1
# tornado                   6.4.2
# tqdm                      4.67.1
# traitlets                 5.14.3
# types-python-dateutil     2.9.0.20241206
# typing_extensions         4.12.2
# uri-template              1.3.0
# urllib3                   2.2.3
# wcwidth                   0.2.13
# webcolors                 24.11.1
# webencodings              0.5.1
# websocket-client          1.8.0
# widgetsnbextension        4.0.13
# zipp                      3.21.0
#
# [notice] A new release of pip is available: 23.0.1 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
# !pip install python-dotenv
# !pip install numpy
# !pip install trulens_eval
# Out:
# Requirement already satisfied: python-dotenv in ./.venv/lib/python3.9/site-packages (1.0.1)
#
# [notice] A new release of pip is available: 23.0.1 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: numpy in ./.venv/lib/python3.9/site-packages (2.0.2)
#
# [notice] A new release of pip is available: 23.0.1 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# Collecting trulens_eval
#   Downloading trulens_eval-1.2.11-py3-none-any.whl (37 kB)
# Collecting trulens-feedback<2.0.0,>=1.0.0
#   Downloading trulens_feedback-1.2.11-py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.3/46.3 kB 837.6 kB/s eta 0:00:0031m96.4 MB/s eta 0:00:01
# Collecting trulens-dashboard<2.0.0,>=1.0.0
#   Downloading trulens_dashboard-1.2.11-py3-none-any.whl (603 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 603.4/603.4 kB 1.5 MB/s eta 0:00:000:00:010:00:01:01
# Collecting trulens-core<2.0.0,>=1.0.0
#   Downloading trulens_core-1.2.11-py3-none-any.whl (232 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.9/232.9 kB 2.3 MB/s eta 0:00:002.3 MB/s eta 0:00:01
# Collecting importlib-resources<7.0,>=6.0
#   Using cached importlib_resources-6.4.5-py3-none-any.whl (36 kB)
# Collecting munch<3.0,>=2.5
#   Downloading munch-2.5.0-py2.py3-none-any.whl (10 kB)
# Collecting dill>=0.3.8
#   Downloading dill-0.3.9-py3-none-any.whl (119 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.4/119.4 kB 1.0 MB/s eta 0:00:00 MB/s eta 0:00:01
# Collecting opentelemetry-api<2.0.0,>=1.0.0
#   Downloading opentelemetry_api-1.29.0-py3-none-any.whl (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.3/64.3 kB 1.2 MB/s eta 0:00:003 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.23.0 in ./.venv/lib/python3.9/site-packages (from trulens-core<2.0.0,>=1.0.0->trulens_eval) (2.0.2)
# Collecting pandas>=1.0.0
#   Using cached pandas-2.2.3-cp39-cp39-macosx_11_0_arm64.whl (11.3 MB)
# Collecting rich<14.0,>=13.6
#   Downloading rich-13.9.4-py3-none-any.whl (242 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.4/242.4 kB 1.2 MB/s eta 0:00:001.4 MB/s eta 0:00:01
# Requirement already satisfied: pydantic<3.0.0,>=2.4.2 in ./.venv/lib/python3.9/site-packages (from trulens-core<2.0.0,>=1.0.0->trulens_eval) (2.10.4)
# Collecting alembic<2.0.0,>=1.8.1
#   Downloading alembic-1.14.0-py3-none-any.whl (233 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.5/233.5 kB 1.1 MB/s eta 0:00:001.2 MB/s eta 0:00:01
# Collecting trulens-otel-semconv<2.0.0,>=1.0.0
#   Downloading trulens_otel_semconv-1.2.11-py3-none-any.whl (5.2 kB)
# Requirement already satisfied: nest-asyncio<2.0,>=1.5 in ./.venv/lib/python3.9/site-packages (from trulens-core<2.0.0,>=1.0.0->trulens_eval) (1.6.0)
# Requirement already satisfied: python-dotenv<2.0,>=0.21 in ./.venv/lib/python3.9/site-packages (from trulens-core<2.0.0,>=1.0.0->trulens_eval) (1.0.1)
# Collecting sqlalchemy<3.0,>=2.0
#   Downloading SQLAlchemy-2.0.36-cp39-cp39-macosx_11_0_arm64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 792.3 kB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: typing_extensions<5.0,>=4.9 in ./.venv/lib/python3.9/site-packages (from trulens-core<2.0.0,>=1.0.0->trulens_eval) (4.12.2)
# Requirement already satisfied: requests<3.0,>=2.31 in ./.venv/lib/python3.9/site-packages (from trulens-core<2.0.0,>=1.0.0->trulens_eval) (2.32.3)
# Collecting opentelemetry-sdk<2.0.0,>=1.0.0
#   Downloading opentelemetry_sdk-1.29.0-py3-none-any.whl (118 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.1/118.1 kB 2.0 MB/s eta 0:00:002.3 MB/s eta 0:00:01
# Requirement already satisfied: packaging>=23.0 in ./.venv/lib/python3.9/site-packages (from trulens-core<2.0.0,>=1.0.0->trulens_eval) (24.2)
# Requirement already satisfied: ipywidgets>=7.1.2 in ./.venv/lib/python3.9/site-packages (from trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (8.1.5)
# Requirement already satisfied: traitlets<6.0.0,>=5.0.5 in ./.venv/lib/python3.9/site-packages (from trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (5.14.3)
# Requirement already satisfied: jupyter<2,>=1 in ./.venv/lib/python3.9/site-packages (from trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (1.1.1)
# Collecting psutil<6.0,>=5.9
#   Downloading psutil-5.9.8-cp38-abi3-macosx_11_0_arm64.whl (249 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 249.9/249.9 kB 1.1 MB/s eta 0:00:001.2 MB/s eta 0:00:01
# Collecting plotly<6.0.0,>=5.22.0
#   Downloading plotly-5.24.1-py3-none-any.whl (19.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.1/19.1 MB 1.2 MB/s eta 0:00:00m eta 0:00:010:00:01m
# Collecting streamlit<2.0,>=1.35
#   Downloading streamlit-1.41.1-py2.py3-none-any.whl (9.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 1.1 MB/s eta 0:00:00m eta 0:00:010:00:010m
# Collecting nltk<4.0.0,>=3.9.1
#   Downloading nltk-3.9.1-py3-none-any.whl (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 901.7 kB/s eta 0:00:001m913.0 kB/s eta 0:00:01
# Collecting scikit-learn<2.0.0,>=1.3.0
#   Using cached scikit_learn-1.6.0-cp39-cp39-macosx_12_0_arm64.whl (11.1 MB)
# Collecting scipy>=1.11.1
#   Using cached scipy-1.13.1-cp39-cp39-macosx_12_0_arm64.whl (30.3 MB)
# Collecting Mako
#   Downloading Mako-1.3.8-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 316.4 kB/s eta 0:00:00 kB/s eta 0:00:01
# Requirement already satisfied: zipp>=3.1.0 in ./.venv/lib/python3.9/site-packages (from importlib-resources<7.0,>=6.0->trulens-core<2.0.0,>=1.0.0->trulens_eval) (3.21.0)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in ./.venv/lib/python3.9/site-packages (from ipywidgets>=7.1.2->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (3.0.13)
# Requirement already satisfied: comm>=0.1.3 in ./.venv/lib/python3.9/site-packages (from ipywidgets>=7.1.2->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (0.2.2)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in ./.venv/lib/python3.9/site-packages (from ipywidgets>=7.1.2->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (4.0.13)
# Requirement already satisfied: ipython>=6.1.0 in ./.venv/lib/python3.9/site-packages (from ipywidgets>=7.1.2->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (8.18.1)
# Requirement already satisfied: notebook in ./.venv/lib/python3.9/site-packages (from jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (7.3.1)
# Requirement already satisfied: jupyterlab in ./.venv/lib/python3.9/site-packages (from jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (4.3.4)
# Requirement already satisfied: nbconvert in ./.venv/lib/python3.9/site-packages (from jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (7.16.4)
# Requirement already satisfied: jupyter-console in ./.venv/lib/python3.9/site-packages (from jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (6.6.3)
# Requirement already satisfied: ipykernel in ./.venv/lib/python3.9/site-packages (from jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (6.29.5)
# Requirement already satisfied: six in ./.venv/lib/python3.9/site-packages (from munch<3.0,>=2.5->trulens-core<2.0.0,>=1.0.0->trulens_eval) (1.17.0)
# Collecting click
#   Using cached click-8.1.7-py3-none-any.whl (97 kB)
# Collecting joblib
#   Using cached joblib-1.4.2-py3-none-any.whl (301 kB)
# Requirement already satisfied: tqdm in ./.venv/lib/python3.9/site-packages (from nltk<4.0.0,>=3.9.1->trulens-feedback<2.0.0,>=1.0.0->trulens_eval) (4.67.1)
# Collecting regex>=2021.8.3
#   Downloading regex-2024.11.6-cp39-cp39-macosx_11_0_arm64.whl (284 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 284.6/284.6 kB 966.5 kB/s eta 0:00:001m918.8 kB/s eta 0:00:01
# Requirement already satisfied: importlib-metadata<=8.5.0,>=6.0 in ./.venv/lib/python3.9/site-packages (from opentelemetry-api<2.0.0,>=1.0.0->trulens-core<2.0.0,>=1.0.0->trulens_eval) (8.5.0)
# Collecting deprecated>=1.2.6
#   Downloading Deprecated-1.2.15-py2.py3-none-any.whl (9.9 kB)
# Collecting opentelemetry-semantic-conventions==0.50b0
#   Downloading opentelemetry_semantic_conventions-0.50b0-py3-none-any.whl (166 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.6/166.6 kB 703.5 kB/s eta 0:00:000:00:01m eta 0:00:01
# Collecting tzdata>=2022.7
#   Using cached tzdata-2024.2-py2.py3-none-any.whl (346 kB)
# Collecting pytz>=2020.1
#   Using cached pytz-2024.2-py2.py3-none-any.whl (508 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.9/site-packages (from pandas>=1.0.0->trulens-core<2.0.0,>=1.0.0->trulens_eval) (2.9.0.post0)
# Collecting tenacity>=6.2.0
#   Downloading tenacity-9.0.0-py3-none-any.whl (28 kB)
# Requirement already satisfied: pydantic-core==2.27.2 in ./.venv/lib/python3.9/site-packages (from pydantic<3.0.0,>=2.4.2->trulens-core<2.0.0,>=1.0.0->trulens_eval) (2.27.2)
# Requirement already satisfied: annotated-types>=0.6.0 in ./.venv/lib/python3.9/site-packages (from pydantic<3.0.0,>=2.4.2->trulens-core<2.0.0,>=1.0.0->trulens_eval) (0.7.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.9/site-packages (from requests<3.0,>=2.31->trulens-core<2.0.0,>=1.0.0->trulens_eval) (2024.12.14)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.9/site-packages (from requests<3.0,>=2.31->trulens-core<2.0.0,>=1.0.0->trulens_eval) (2.2.3)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.9/site-packages (from requests<3.0,>=2.31->trulens-core<2.0.0,>=1.0.0->trulens_eval) (3.10)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.9/site-packages (from requests<3.0,>=2.31->trulens-core<2.0.0,>=1.0.0->trulens_eval) (3.4.0)
# Collecting markdown-it-py>=2.2.0
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./.venv/lib/python3.9/site-packages (from rich<14.0,>=13.6->trulens-core<2.0.0,>=1.0.0->trulens_eval) (2.18.0)
# Collecting threadpoolctl>=3.1.0
#   Using cached threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Collecting blinker<2,>=1.0.0
#   Downloading blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Requirement already satisfied: tornado<7,>=6.0.3 in ./.venv/lib/python3.9/site-packages (from streamlit<2.0,>=1.35->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (6.4.2)
# Collecting pyarrow>=7.0
#   Downloading pyarrow-18.1.0-cp39-cp39-macosx_12_0_arm64.whl (29.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.5/29.5 MB 988.5 kB/s eta 0:00:00m eta 0:00:0136m0:00:01m
# Collecting toml<2,>=0.10.1
#   Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Collecting altair<6,>=4.0
#   Downloading altair-5.5.0-py3-none-any.whl (731 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.2/731.2 kB 1.3 MB/s eta 0:00:00m eta 0:00:010:01:01
# Collecting pydeck<1,>=0.8.0b4
#   Downloading pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 941.9 kB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting gitpython!=3.1.19,<4,>=3.0.7
#   Downloading GitPython-3.1.43-py3-none-any.whl (207 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 1.1 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting pillow<12,>=7.1.0
#   Using cached pillow-11.0.0-cp39-cp39-macosx_11_0_arm64.whl (3.0 MB)
# Collecting cachetools<6,>=4.0
#   Downloading cachetools-5.5.0-py3-none-any.whl (9.5 kB)
# Collecting protobuf<6,>=3.20
#   Downloading protobuf-5.29.2-cp38-abi3-macosx_10_9_universal2.whl (417 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 417.8/417.8 kB 1.3 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# Requirement already satisfied: jsonschema>=3.0 in ./.venv/lib/python3.9/site-packages (from altair<6,>=4.0->streamlit<2.0,>=1.35->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (4.23.0)
# Requirement already satisfied: jinja2 in ./.venv/lib/python3.9/site-packages (from altair<6,>=4.0->streamlit<2.0,>=1.35->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (3.1.4)
# Collecting narwhals>=1.14.2
#   Downloading narwhals-1.18.4-py3-none-any.whl (251 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 251.3/251.3 kB 1.1 MB/s eta 0:00:001.1 MB/s eta 0:00:01
# Collecting wrapt<2,>=1.10
#   Downloading wrapt-1.17.0-cp39-cp39-macosx_11_0_arm64.whl (38 kB)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 1.0 MB/s eta 0:00:00 MB/s eta 0:00:01
# Requirement already satisfied: stack-data in ./.venv/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets>=7.1.2->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (0.6.3)
# Requirement already satisfied: jedi>=0.16 in ./.venv/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets>=7.1.2->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (0.19.2)
# Requirement already satisfied: matplotlib-inline in ./.venv/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets>=7.1.2->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in ./.venv/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets>=7.1.2->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (3.0.48)
# Requirement already satisfied: exceptiongroup in ./.venv/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets>=7.1.2->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (1.2.2)
# Requirement already satisfied: pexpect>4.3 in ./.venv/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets>=7.1.2->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (4.9.0)
# Requirement already satisfied: decorator in ./.venv/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets>=7.1.2->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (5.1.1)
# Collecting mdurl~=0.1
#   Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Requirement already satisfied: debugpy>=1.6.5 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (1.8.11)
# Requirement already satisfied: appnope in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (0.1.4)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (5.7.2)
# Requirement already satisfied: jupyter-client>=6.1.12 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (8.6.3)
# Requirement already satisfied: pyzmq>=24 in ./.venv/lib/python3.9/site-packages (from ipykernel->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (26.2.0)
# Requirement already satisfied: setuptools>=40.8.0 in ./.venv/lib/python3.9/site-packages (from jupyterlab->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (58.1.0)
# Requirement already satisfied: async-lru>=1.0.0 in ./.venv/lib/python3.9/site-packages (from jupyterlab->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (2.0.4)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in ./.venv/lib/python3.9/site-packages (from jupyterlab->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (2.27.3)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in ./.venv/lib/python3.9/site-packages (from jupyterlab->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (2.14.2)
# Requirement already satisfied: notebook-shim>=0.2 in ./.venv/lib/python3.9/site-packages (from jupyterlab->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (0.2.4)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in ./.venv/lib/python3.9/site-packages (from jupyterlab->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (2.2.5)
# Requirement already satisfied: tomli>=1.2.2 in ./.venv/lib/python3.9/site-packages (from jupyterlab->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (2.2.1)
# Requirement already satisfied: httpx>=0.25.0 in ./.venv/lib/python3.9/site-packages (from jupyterlab->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (0.28.1)
# Requirement already satisfied: MarkupSafe>=0.9.2 in ./.venv/lib/python3.9/site-packages (from Mako->alembic<2.0.0,>=1.8.1->trulens-core<2.0.0,>=1.0.0->trulens_eval) (3.0.2)
# Requirement already satisfied: nbformat>=5.7 in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (5.10.4)
# Requirement already satisfied: tinycss2 in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (1.4.0)
# Requirement already satisfied: jupyterlab-pygments in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (0.3.0)
# Requirement already satisfied: beautifulsoup4 in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (4.12.3)
# Requirement already satisfied: mistune<4,>=2.0.3 in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (0.10.2)
# Requirement already satisfied: bleach!=5.0.0 in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (6.2.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (1.5.1)
# Requirement already satisfied: defusedxml in ./.venv/lib/python3.9/site-packages (from nbconvert->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (0.7.1)
# Requirement already satisfied: webencodings in ./.venv/lib/python3.9/site-packages (from bleach!=5.0.0->nbconvert->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (0.5.1)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Requirement already satisfied: anyio in ./.venv/lib/python3.9/site-packages (from httpx>=0.25.0->jupyterlab->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (4.7.0)
# Requirement already satisfied: httpcore==1.* in ./.venv/lib/python3.9/site-packages (from httpx>=0.25.0->jupyterlab->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in ./.venv/lib/python3.9/site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (0.14.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in ./.venv/lib/python3.9/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=7.1.2->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (0.8.4)
# Requirement already satisfied: attrs>=22.2.0 in ./.venv/lib/python3.9/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit<2.0,>=1.35->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (24.3.0)
# Requirement already satisfied: referencing>=0.28.4 in ./.venv/lib/python3.9/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit<2.0,>=1.35->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in ./.venv/lib/python3.9/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit<2.0,>=1.35->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (0.22.3)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in ./.venv/lib/python3.9/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit<2.0,>=1.35->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (2024.10.1)
# Requirement already satisfied: platformdirs>=2.5 in ./.venv/lib/python3.9/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (4.3.6)
# Requirement already satisfied: terminado>=0.8.3 in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (1.8.0)
# Requirement already satisfied: overrides>=5.0 in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (7.7.0)
# Requirement already satisfied: send2trash>=1.8.2 in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (1.8.3)
# Requirement already satisfied: prometheus-client>=0.9 in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (0.21.1)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (0.5.3)
# Requirement already satisfied: argon2-cffi>=21.1 in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (23.1.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in ./.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (0.11.0)
# Requirement already satisfied: babel>=2.10 in ./.venv/lib/python3.9/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (2.16.0)
# Requirement already satisfied: json5>=0.9.0 in ./.venv/lib/python3.9/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (0.10.0)
# Requirement already satisfied: fastjsonschema>=2.15 in ./.venv/lib/python3.9/site-packages (from nbformat>=5.7->nbconvert->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (2.21.1)
# Requirement already satisfied: ptyprocess>=0.5 in ./.venv/lib/python3.9/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets>=7.1.2->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (0.7.0)
# Requirement already satisfied: wcwidth in ./.venv/lib/python3.9/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets>=7.1.2->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (0.2.13)
# Requirement already satisfied: soupsieve>1.2 in ./.venv/lib/python3.9/site-packages (from beautifulsoup4->nbconvert->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (2.6)
# Requirement already satisfied: pure-eval in ./.venv/lib/python3.9/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.1.2->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (0.2.3)
# Requirement already satisfied: asttokens>=2.1.0 in ./.venv/lib/python3.9/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.1.2->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (3.0.0)
# Requirement already satisfied: executing>=1.2.0 in ./.venv/lib/python3.9/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.1.2->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (2.1.0)
# Requirement already satisfied: sniffio>=1.1 in ./.venv/lib/python3.9/site-packages (from anyio->httpx>=0.25.0->jupyterlab->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in ./.venv/lib/python3.9/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (21.2.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in ./.venv/lib/python3.9/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (3.2.1)
# Requirement already satisfied: pyyaml>=5.3 in ./.venv/lib/python3.9/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (6.0.2)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in ./.venv/lib/python3.9/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (0.1.1)
# Requirement already satisfied: rfc3339-validator in ./.venv/lib/python3.9/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (0.1.4)
# Requirement already satisfied: uri-template in ./.venv/lib/python3.9/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit<2.0,>=1.35->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (1.3.0)
# Requirement already satisfied: fqdn in ./.venv/lib/python3.9/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit<2.0,>=1.35->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (1.5.1)
# Requirement already satisfied: isoduration in ./.venv/lib/python3.9/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit<2.0,>=1.35->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in ./.venv/lib/python3.9/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit<2.0,>=1.35->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (3.0.0)
# Requirement already satisfied: webcolors>=24.6.0 in ./.venv/lib/python3.9/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit<2.0,>=1.35->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (24.11.1)
# Requirement already satisfied: cffi>=1.0.1 in ./.venv/lib/python3.9/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (1.17.1)
# Requirement already satisfied: pycparser in ./.venv/lib/python3.9/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (2.22)
# Requirement already satisfied: arrow>=0.15.0 in ./.venv/lib/python3.9/site-packages (from isoduration->jsonschema>=3.0->altair<6,>=4.0->streamlit<2.0,>=1.35->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in ./.venv/lib/python3.9/site-packages (from arrow>=0.15.0->isoduration->jsonschema>=3.0->altair<6,>=4.0->streamlit<2.0,>=1.35->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (2.9.0.20241206)
# Installing collected packages: pytz, wrapt, tzdata, toml, threadpoolctl, tenacity, sqlalchemy, smmap, scipy, regex, pyarrow, psutil, protobuf, pillow, narwhals, munch, mdurl, Mako, joblib, importlib-resources, dill, click, cachetools, blinker, scikit-learn, pydeck, plotly, pandas, nltk, markdown-it-py, gitdb, deprecated, alembic, rich, opentelemetry-api, gitpython, opentelemetry-semantic-conventions, altair, trulens-otel-semconv, streamlit, opentelemetry-sdk, trulens-core, trulens-feedback, trulens-dashboard, trulens_eval
#   Attempting uninstall: psutil
#     Found existing installation: psutil 6.1.0
#     Uninstalling psutil-6.1.0:
#       Successfully uninstalled psutil-6.1.0
# Successfully installed Mako-1.3.8 alembic-1.14.0 altair-5.5.0 blinker-1.9.0 cachetools-5.5.0 click-8.1.7 deprecated-1.2.15 dill-0.3.9 gitdb-4.0.11 gitpython-3.1.43 importlib-resources-6.4.5 joblib-1.4.2 markdown-it-py-3.0.0 mdurl-0.1.2 munch-2.5.0 narwhals-1.18.4 nltk-3.9.1 opentelemetry-api-1.29.0 opentelemetry-sdk-1.29.0 opentelemetry-semantic-conventions-0.50b0 pandas-2.2.3 pillow-11.0.0 plotly-5.24.1 protobuf-5.29.2 psutil-5.9.8 pyarrow-18.1.0 pydeck-0.9.1 pytz-2024.2 regex-2024.11.6 rich-13.9.4 scikit-learn-1.6.0 scipy-1.13.1 smmap-5.0.1 sqlalchemy-2.0.36 streamlit-1.41.1 tenacity-9.0.0 threadpoolctl-3.5.0 toml-0.10.2 trulens-core-1.2.11 trulens-dashboard-1.2.11 trulens-feedback-1.2.11 trulens-otel-semconv-1.2.11 trulens_eval-1.2.11 tzdata-2024.2 wrapt-1.17.0
#
# [notice] A new release of pip is available: 23.0.1 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
# !pip install trulens-providers-openai
# Out:
# zsh:1: 1.0.0 not found

# %%
uw_info = """
The University of Washington, founded in 1861 in Seattle, is a public research university
with over 45,000 students across three campuses in Seattle, Tacoma, and Bothell.
As the flagship institution of the six public universities in Washington state,
UW encompasses over 500 buildings and 20 million square feet of space,
including one of the largest library systems in the world.
"""

wsu_info = """
Washington State University, commonly known as WSU, founded in 1890, is a public research university in Pullman, Washington.
With multiple campuses across the state, it is the state's second largest institution of higher education.
WSU is known for its programs in veterinary medicine, agriculture, engineering, architecture, and pharmacy.
"""

seattle_info = """
Seattle, a city on Puget Sound in the Pacific Northwest, is surrounded by water, mountains and evergreen forests, and contains thousands of acres of parkland.
It's home to a large tech industry, with Microsoft and Amazon headquartered in its metropolitan area.
The futuristic Space Needle, a legacy of the 1962 World's Fair, is its most iconic landmark.
"""

starbucks_info = """
Starbucks Corporation is an American multinational chain of coffeehouses and roastery reserves headquartered in Seattle, Washington.
As the world's largest coffeehouse chain, Starbucks is seen to be the main representation of the United States' second wave of coffee culture.
"""

newzealand_info = """
New Zealand is an island country located in the southwestern Pacific Ocean. It comprises two main landmasses—the North Island and the South Island—and over 700 smaller islands.
The country is known for its stunning landscapes, ranging from lush forests and mountains to beaches and lakes. New Zealand has a rich cultural heritage, with influences from 
both the indigenous Māori people and European settlers. The capital city is Wellington, while the largest city is Auckland. New Zealand is also famous for its adventure tourism,
including activities like bungee jumping, skiing, and hiking.
"""

# %%
import chromadb
from chromadb.utils.embedding_functions import OpenAIEmbeddingFunction
import os

embedding_function = OpenAIEmbeddingFunction(
    api_key=os.environ.get("OPENAI_API_KEY"),
    model_name="text-embedding-ada-002",
)


chroma_client = chromadb.Client()
vector_store = chroma_client.get_or_create_collection(
    name="Washington", embedding_function=embedding_function
)

# %%
vector_store.add("uw_info", documents=uw_info)
vector_store.add("wsu_info", documents=wsu_info)
vector_store.add("seattle_info", documents=seattle_info)
vector_store.add("starbucks_info", documents=starbucks_info)
vector_store.add("newzealand_info", documents=newzealand_info)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# File ~/meetup_cs224n/RAG/.venv/lib/python3.9/site-packages/chromadb/api/models/CollectionCommon.py:90, in validation_context.<locals>.decorator.<locals>.wrapper(self, *args, **kwargs)
#      89 try:
# ---> 90     return func(self, *args, **kwargs)
#      91 except Exception as e:
#
# File ~/meetup_cs224n/RAG/.venv/lib/python3.9/site-packages/chromadb/api/models/CollectionCommon.py:213, in CollectionCommon._validate_and_prepare_add_request(self, ids, embeddings, metadatas, documents, images, uris)
#     212     validate_record_set_for_embedding(record_set=add_records)
# --> 213     add_embeddings = self._embed_record_set(record_set=add_records)
#     214 else:
#
# File ~/meetup_cs224n/RAG/.venv/lib/python3.9/site-packages/chromadb/api/models/CollectionCommon.py:526, in CollectionCommon._embed_record_set(self, record_set, embeddable_fields)
#     525         else:
# --> 526             return self._embed(input=record_set[field])  # type: ignore[literal-required]
#     527 raise ValueError(
#     528     "Record does not contain any non-None fields that can be embedded."
#     529     f"Embeddable Fields: {embeddable_fields}"
#     530     f"Record Fields: {record_set}"
#     531 )
#
# File ~/meetup_cs224n/RAG/.venv/lib/python3.9/site-packages/chromadb/api/models/CollectionCommon.py:539, in CollectionCommon._embed(self, input)
#     535     raise ValueError(
#     536         "You must provide an embedding function to compute embeddings."
#     537         "https://docs.trychroma.com/guides/embeddings"
#     538     )
# --> 539 return self._embedding_function(input=input)
#
# File ~/meetup_cs224n/RAG/.venv/lib/python3.9/site-packages/chromadb/api/types.py:466, in EmbeddingFunction.__init_subclass__.<locals>.__call__(self, input)
#     465 def __call__(self: EmbeddingFunction[D], input: D) -> Embeddings:
# --> 466     result = call(self, input)
#     467     assert result is not None
#
# File ~/meetup_cs224n/RAG/.venv/lib/python3.9/site-packages/chromadb/utils/embedding_functions/openai_embedding_function.py:113, in OpenAIEmbeddingFunction.__call__(self, input)
#     112 if self._v1:
# --> 113     embeddings = self._client.create(
#     114         input=input,
#     115         model=self._deployment_id or self._model_name,
#     116         dimensions=self._dimensions,
#     117     ).data
#     119     # Sort resulting embeddings by index
#
# File ~/meetup_cs224n/RAG/.venv/lib/python3.9/site-packages/openai/resources/embeddings.py:124, in Embeddings.create(self, input, model, dimensions, encoding_format, user, extra_headers, extra_query, extra_body, timeout)
#     122     return obj
# --> 124 return self._post(
#     125     "/embeddings",
#     126     body=maybe_transform(params, embedding_create_params.EmbeddingCreateParams),
#     127     options=make_request_options(
#     128         extra_headers=extra_headers,
#     129         extra_query=extra_query,
#     130         extra_body=extra_body,
#     131         timeout=timeout,
#     132         post_parser=parser,
#     133     ),
#     134     cast_to=CreateEmbeddingResponse,
#     135 )
#
# File ~/meetup_cs224n/RAG/.venv/lib/python3.9/site-packages/openai/_base_client.py:1280, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1277 opts = FinalRequestOptions.construct(
#    1278     method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1279 )
# -> 1280 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/meetup_cs224n/RAG/.venv/lib/python3.9/site-packages/openai/_base_client.py:957, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     955     retries_taken = 0
# --> 957 return self._request(
#     958     cast_to=cast_to,
#     959     options=options,
#     960     stream=stream,
#     961     stream_cls=stream_cls,
#     962     retries_taken=retries_taken,
#     963 )
#
# File ~/meetup_cs224n/RAG/.venv/lib/python3.9/site-packages/openai/_base_client.py:1046, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1045     err.response.close()
# -> 1046     return self._retry_request(
#    1047         input_options,
#    1048         cast_to,
#    1049         retries_taken=retries_taken,
#    1050         response_headers=err.response.headers,
#    1051         stream=stream,
#    1052         stream_cls=stream_cls,
#    1053     )
#    1055 # If the response is streamed then we need to explicitly read the response
#    1056 # to completion before attempting to access the response text.
#
# File ~/meetup_cs224n/RAG/.venv/lib/python3.9/site-packages/openai/_base_client.py:1095, in SyncAPIClient._retry_request(self, options, cast_to, retries_taken, response_headers, stream, stream_cls)
#    1093 time.sleep(timeout)
# -> 1095 return self._request(
#    1096     options=options,
#    1097     cast_to=cast_to,
#    1098     retries_taken=retries_taken + 1,
#    1099     stream=stream,
#    1100     stream_cls=stream_cls,
#    1101 )
#
# File ~/meetup_cs224n/RAG/.venv/lib/python3.9/site-packages/openai/_base_client.py:1046, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1045     err.response.close()
# -> 1046     return self._retry_request(
#    1047         input_options,
#    1048         cast_to,
#    1049         retries_taken=retries_taken,
#    1050         response_headers=err.response.headers,
#    1051         stream=stream,
#    1052         stream_cls=stream_cls,
#    1053     )
#    1055 # If the response is streamed then we need to explicitly read the response
#    1056 # to completion before attempting to access the response text.
#
# File ~/meetup_cs224n/RAG/.venv/lib/python3.9/site-packages/openai/_base_client.py:1095, in SyncAPIClient._retry_request(self, options, cast_to, retries_taken, response_headers, stream, stream_cls)
#    1093 time.sleep(timeout)
# -> 1095 return self._request(
#    1096     options=options,
#    1097     cast_to=cast_to,
#    1098     retries_taken=retries_taken + 1,
#    1099     stream=stream,
#    1100     stream_cls=stream_cls,
#    1101 )
#
# File ~/meetup_cs224n/RAG/.venv/lib/python3.9/site-packages/openai/_base_client.py:1061, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1060     log.debug("Re-raising status error")
# -> 1061     raise self._make_status_error_from_response(err.response) from None
#    1063 return self._process_response(
#    1064     cast_to=cast_to,
#    1065     options=options,
#    (...)
#    1069     retries_taken=retries_taken,
#    1070 )
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 vector_store.add("uw_info", documents=uw_info)
#       2 vector_store.add("wsu_info", documents=wsu_info)
#       3 vector_store.add("seattle_info", documents=seattle_info)
#
# File ~/meetup_cs224n/RAG/.venv/lib/python3.9/site-packages/chromadb/api/models/Collection.py:81, in Collection.add(self, ids, embeddings, metadatas, documents, images, uris)
#      46 def add(
#      47     self,
#      48     ids: OneOrMany[ID],
#    (...)
#      58     uris: Optional[OneOrMany[URI]] = None,
#      59 ) -> None:
#      60     """Add embeddings to the data store.
#      61     Args:
#      62         ids: The ids of the embeddings you wish to add
#    (...)
#      78
#      79     """
# ---> 81     add_request = self._validate_and_prepare_add_request(
#      82         ids=ids,
#      83         embeddings=embeddings,
#      84         metadatas=metadatas,
#      85         documents=documents,
#      86         images=images,
#      87         uris=uris,
#      88     )
#      90     self._client._add(
#      91         collection_id=self.id,
#      92         ids=add_request["ids"],
#    (...)
#      98         database=self.database,
#      99     )
#
# File ~/meetup_cs224n/RAG/.venv/lib/python3.9/site-packages/chromadb/api/models/CollectionCommon.py:93, in validation_context.<locals>.decorator.<locals>.wrapper(self, *args, **kwargs)
#      91 except Exception as e:
#      92     msg = f"{str(e)} in {name}."
# ---> 93     raise type(e)(msg).with_traceback(e.__traceback__)
#
# TypeError: __init__() missing 2 required keyword-only arguments: 'response' and 'body'
